# %%
import numpy as np

a = np.array([1, 2, 3])

print(a)
# Out:
# [1 2 3]

# %%
b = [2, 3, 4]

print(a)
print(b)
# Out:
# [1 2 3]
# [2, 3, 4]

# %%
c = np.array([[1, 2], [3, 4]])
print(a)
print(b)
print(c)
# Out:
# [1 2 3]
# [2, 3, 4]
# [[1 2]
#  [3 4]]

# %%
print(a + 2)
print(np.sqrt(a))

print(np.dot(a, b))
# Out:
# [3 4 5]
# [1.         1.41421356 1.73205081]
# 20

# %%
xyz = np.array([1, 'foo', 2])
print(xyz)
# Out:
# ['1' 'foo' '2']
